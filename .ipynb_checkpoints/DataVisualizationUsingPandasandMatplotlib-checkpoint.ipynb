# %%
 import pandas as pd

# %%
from matplotlib import pyplot as mpl

# %%
dataSample = pd.read_csv('countries-table.csv')  
topFive = dataSample.head(5)

# %%
mpl.bar(topFive.country, topFive.pop2023)
mpl.title("Top 5 Countries")
mpl.show()
